# %%
from BSParser import KTRace
from die import Die

harlequins = KTRace('Harlequins')
tau = KTRace("T'au Empire")

# %%
player = harlequins.models['Player']
fire_warrior = tau.models["Fire Warrior Shas'la"]

# %%
d6 = Die(6)
